# %%
import pandas as pd

# %%
df=pd.read_csv('Furniture Price Prediction.csv')

# %%
df
# Out:
#                                               furniture  \
# 0                    Bed side table with storage shelf
# 1                    Bed side table with storage shelf
# 2                               Modern Zigzag TV Table
# 3                     Bedside table with storage shelf
# 4     Wall Mounted TV Unit with Cabinet TV Stand Uni...
# ...                                                 ...
# 1995  Casio Standard Analogue Ladys Standard Analog ...
# 1996                          Coffee table + side table
# 1997                                 Ben Togo Baby Bed
# 1998               Cloud memory foam mattress (medical)
# 1999                         Comfy memory foam mattress
#
#                                                    type  \
# 0                                     Home Decor Center
# 1                                           Modern Home
# 2                                           Modern Home
# 3                                           Modern Home
# ...

# %%
df.dtypes
# Out:
# furniture     object
# type          object
# url           object
# rate         float64
# delivery     float64
# sale          object
# price        float64
# dtype: object

# %%
df.columns
# Out:
# Index(['furniture', 'type', 'url', 'rate', 'delivery', 'sale', 'price'], dtype='object')

# %%
df[df['price']> 2000]
# Out:
#                                               furniture  \
# 0                    Bed side table with storage shelf
# 5               Modern Home Modern Tv Table - Black Oak
# 6                        Modern desk with side shelves
# 7                                      Modern TV table
# 10                                   Modern side table
# ...                                                 ...
# 1993                                Habitat (Platinum)
# 1995  Casio Standard Analogue Ladys Standard Analog ...
# 1996                          Coffee table + side table
# 1998               Cloud memory foam mattress (medical)
# 1999                         Comfy memory foam mattress
#
#                                                    type  \
# 0                                     Home Decor Center
# 5               Modern Home Modern Tv Table   Black Oak
# 6                                           Modern Home
# 7                                           Modern Home
# ...

# %%
type_df = df.groupby("type")["price"].mean().sort_values(ascending =False).reset_index()

# %%
df.groupby("type")["price"].mean().sort_values(ascending =False)
# Out:
# type
# Art House            L shape                            55000.000000
# Art House                  L                            49000.000000
# Art House           L shape                             45000.000000
# Art House                                               16362.600000
# Hub Furniture                                           16243.333333
#                                                             ...
# Family Bed                                                       NaN
# Fantazzia                                                        NaN
# Fishing Chair Portable Outdoor Folding Fishing Chair             NaN
# Floral Shelf Brackets                                            NaN
# Furniture Pad Stackable Bed Lifts Floor Protector                NaN
# Name: price, Length: 592, dtype: float64

# %%
type_df[type_df['type'].str.contains("Art House")]
# Out:
#                            type    price
# 0  Art House            L shape  55000.0
# 1  Art House                  L  49000.0
# 2   Art House           L shape  45000.0
# 3                     Art House  16362.6

# %%
Art House L shape
Art House L shape
